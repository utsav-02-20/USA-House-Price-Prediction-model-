# %%
# Data
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Split data
from sklearn.model_selection import train_test_split

#model train
from sklearn.linear_model import LinearRegression

#model Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#randon forest regressor

from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv('USA_Housing - USA_Housing.csv')
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# target value is Price

# variables are avg home age , avg no of room , avg no of bedsrooms , area population , address

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='str')

# %%
dependent_list = ["Price"]

independent_list = [
    "Avg. Area Income",
    "Avg. Area House Age",
    "Avg. Area Number of Rooms",
    "Avg. Area Number of Bedrooms",
    "Area Population"
]

for col in independent_list:
    plt.figure(figsize=(7, 4))
    
    plt.scatter(data[col], data["Price"])
    
    plt.xlabel(col)
    plt.ylabel("Price")
    plt.title(f"{col} vs Price")
    
    plt.show()

# %%
# heat map of dependence 
plt.figure(figsize=(10, 7))

sns.heatmap(
    data[independent_list + ["Price"]].corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
# data correctness 
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   str
# dtypes: float64(6), str(1)
# memory usage: 273.6 KB

# %%
data[independent_list].describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population
# count                   5000.000000      5000.000000
# mean                       3.981330     36163.516039
# std                        1.234137      9925.650114
# min                        2.000000       172.610686
# ...

# %%
#data price describe 
data["Price"].describe
# Out:
# <bound method NDFrame.describe of 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64>

# %%
x = data[independent_list]

y = data["Price"]

# split data

# %%
# train test split 
x_train , x_test , y_train , y_test = train_test_split(
    x , y , 
    test_size=0.2 , random_state=42
)

# %%
# using linear regration 
model = LinearRegression()

model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
# test model on data which are not seen 
y_pred = model.predict(x_test)

# %%
# for regression 

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# MAE: 80879.09722218332
# MSE: 10089009299.49946
# R2 Score: 0.9179971706985317

# %%
# visualize actual vss predicted 
plt.figure(figsize=(7, 5))

plt.scatter(y_test, y_pred)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted House Prices")

plt.show()

# %%
# create a model for random forest regressor 

# basic configuration
# rf_model = RandomForestRegressor(
#     n_estimators=100,
#     random_state=42
# )

# stronger configuration
rf_model = RandomForestRegressor(
    n_estimators=30000,
    max_depth=None,
    min_samples_split=2,
    random_state=42,
    n_jobs=-1
)

# %%
# train that model on our existing data set 
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=30000, n_jobs=-1, random_state=42)

# %%
# predict values on our test data set 
rf_pred = rf_model.predict(x_test)

# %%
# evaluate the random forest model 
rf_mae = mean_absolute_error(y_test, rf_pred)
rf_mse = mean_squared_error(y_test, rf_pred)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = r2_score(y_test, rf_pred)

print("MAE:", rf_mae)
print("MSE:", rf_mse)
print("RMSE:", rf_rmse)
print("R2 Score:", rf_r2)
# Out:
# MAE: 93881.83056474797
# MSE: 14253367783.280735
# RMSE: 119387.46912168268
# R2 Score: 0.8841495284020201

# %%
# actual vs predicted for rf 
plt.figure(figsize=(7, 5))

plt.scatter(y_test, rf_pred)

# Perfect prediction line
plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Random Forest: Actual vs Predicted Prices")

plt.show()

# %%
# input form user 

new_house = pd.DataFrame([{
    "Avg. Area Income": 70000,
    "Avg. Area House Age": 6.0,
    "Avg. Area Number of Rooms": 7.0,
    "Avg. Area Number of Bedrooms": 4.0,
    "Area Population": 35000
}])

prediction = model.predict(new_house)

print("Predicted House Price:", prediction[0])
# Out:
# Predicted House Price: 1250170.952972008
